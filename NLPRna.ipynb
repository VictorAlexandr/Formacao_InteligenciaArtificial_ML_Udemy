# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# %%
spam = pd.read_csv("spam.csv")
spam.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
spam.shape
# Out:
# (5572, 2)

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(spam['Category'])
print(y)
# Out:
# [0 0 1 ... 0 0 0]

# %%
mensagens = spam['Message'].values
X_train, X_test, y_train, y_test = train_test_split(mensagens, y, test_size=0.3)

# %%
token = Tokenizer(num_words=1000)
token.fit_on_texts(X_train)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# %%
print(X_train)
# Out:
# [[436, 2, 369, 28, 5, 44, 9, 207, 8, 457, 155, 57, 253, 28, 267, 728, 135], [484, 3, 10, 7, 48, 14, 9, 63, 238, 31, 3], [3, 28, 781, 3, 136, 239, 2, 919, 46, 49, 117, 203, 568, 133, 12, 835, 7, 920, 7, 1, 21, 268, 2, 919, 46, 96, 782], [10, 89, 51, 3, 63, 2, 648], [208, 212, 1, 30, 16, 3], [1, 17, 19, 602, 110, 7, 7, 106, 540, 200, 680], [103, 130, 10, 29, 9, 409], [40, 8, 5, 458, 60, 39, 17, 541, 19, 204, 6, 6, 17, 175, 5, 681, 147, 19, 125, 8, 355, 16, 22, 65, 459, 225, 213, 335, 485, 370], [126, 371, 1, 61, 921, 51, 3, 131, 4, 922, 31, 3, 372, 63, 2, 10, 1, 72, 2, 69, 4, 2, 195, 25, 13, 542, 53, 219, 12, 156, 309, 923, 437, 51, 3, 682, 45, 18, 12, 10, 2, 53, 2, 7, 836, 5, 245, 3, 113, 10, 49, 2, 34, 18, 26, 34, 3, 58, 109, 235, 137, 2, 836, 345, 309, 122, 27, 836, 302, 47, 5, 101, 240, 184, 32, 119, 11, 392], [103, 208, 393, 5, 102, 99, 47, 65, 924, 28, 73, 310, 356, 2, 37, 35, 504, 22], [12, 71, 925, 114, 148, 569, 649, 33, 74, 37, 926, 570, 240], [505, 927, 783, 2, 10], [38, 57, 282, 269, 53, 729], [3, 21], [336, 438, 22, 1, 57, 102, 311], [51, 6, 21, 9, 66, 110, 6, 54, 19, 6, 35, 127, 6, 94, 5, 270, 15, 14, 153, 6, 542, 35, 486, 51, 14], [322, 3, 303, 337, 919, 46, 49, 117, 39, 77, 12, 920, 7, 1, 21, 268, 2, 919, 46, 49, 117, 39, 27, 837, 20, 782], [3, 17, 120, 394, 208, 226, 47], [83, 201, 43, 11, 784, 19, 257, 571, 55, 17, 283, 83, 1, 730, 176, 460
 1, 27, 846], [71, 164, 195, 511, 90, 6, 27, 173, 4, 443, 26, 272, 59, 45, 2, 6, 411, 43, 38, 459, 98, 33, 270, 687, 931, 255, 130], [37, 29, 23, 269, 32, 547, 2, 135, 261, 84, 32, 75, 9, 4, 315, 787, 444, 50, 21, 5, 732], [24, 27, 424, 36, 688], [146, 489, 21, 3, 81, 2, 132, 10], [50, 60, 3, 115, 689, 17, 13, 77, 2, 58, 51, 1, 136, 32, 847], [12, 5, 263, 60, 9, 5, 7, 21, 28, 285, 512, 9, 731, 733, 41, 42, 733, 41, 42, 733, 41, 42, 41, 42 ...

# %%
X_train = pad_sequences(X_train, padding="post", maxlen=500)
X_test = pad_sequences(X_test, padding="post", maxlen=500)

# %%
len(token.word_index)
# Out:
# 7519

# %%
X_train
# Out:
# array([[436,   2, 369, ...,   0,   0,   0],
#        [484,   3,  10, ...,   0,   0,   0],
#        [  3,  28, 781, ...,   0,   0,   0],
#        ...,
#        [ 92, 414, 408, ...,   0,   0,   0],
#        [ 47, 148, 198, ...,   0,   0,   0],
#        [292,   1,  62, ...,   0,   0,   0]], dtype=int32)

# %%
modelo = Sequential()
modelo.add(Embedding(input_dim=len(token.word_index),output_dim=50,input_length=500))
modelo.add(Flatten())
modelo.add(Dense(units=10, activation="relu"))
modelo.add(Dropout(0.1))
modelo.add(Dense(units=1, activation='sigmoid'))

# %%
modelo.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 50)           375950
#
#  flatten (Flatten)           (None, 25000)             0
#
#  dense (Dense)               (None, 10)                250010
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 625,971
# Trainable params: 625,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelo.fit(X_train, y_train, epochs=20, batch_size=10, verbose=True, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 390/390 [==============================] - 7s 14ms/step - loss: 0.0703 - accuracy: 0.9221 - val_loss: 0.0466 - val_accuracy: 0.9671
# Epoch 2/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0332 - accuracy: 0.9841 - val_loss: 0.0390 - val_accuracy: 0.9725
# Epoch 3/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0250 - accuracy: 0.9900 - val_loss: 0.0370 - val_accuracy: 0.9701
# Epoch 4/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0188 - accuracy: 0.9931 - val_loss: 0.0258 - val_accuracy: 0.9815
# Epoch 5/20
# 390/390 [==============================] - 4s 12ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0224 - val_accuracy: 0.9821
# Epoch 6/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.0238 - val_accuracy: 0.9791
# Epoch 7/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0204 - val_accuracy: 0.9821
# Epoch 8/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0206 - val_accuracy: 0.9797
# Epoch 9/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.0224 - val_accuracy: 0.9785
# Epoch 10/20
# 390/390 [==============================] - 4s 12ms/step - loss: 0.0056 - accuracy: 0.9972 - val_loss: 0.0204 - val_accuracy: 0.9779
# Epoch 11/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0050 - accuracy: 0.9972 - val_loss: 0.0195 - val_accuracy: 0.9791
# Epoch 12/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0046 - accuracy: 0.9972 - val_loss: 0.0194 - val_accuracy: 0.9797
# Epoch 13/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0042 - accuracy: 0.9972 - val_loss: 0.0183 - val_accuracy: 0.9785
# Epoch 14/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 0.0192 - val_accuracy: 0.9785
# Epoch 15/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.0249 - val_accuracy: 0.9737
# Epoch 16/20
# 390/390 [==============================] - 5s 13ms/step - loss: 0.0039 - accuracy: 0.9969 - val_loss: 0.0169 - val_accuracy: 0.9797
# Epoch 17/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0043 - accuracy: 0.9967 - val_loss: 0.0188 - val_accuracy: 0.9737
# Epoch 18/20
# 390/390 [==============================] - 5s 14ms/step - loss: 0.0036 - accuracy: 0.9967 - val_loss: 0.0163 - val_accuracy: 0.9833
# Epoch 19/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0030 - accuracy: 0.9974 - val_loss: 0.0175 - val_accuracy: 0.9797
# Epoch 20/20
# 390/390 [==============================] - 5s 12ms/step - loss: 0.0029 - accuracy: 0.9974 - val_loss: 0.0173 - val_accuracy: 0.9809

# %%
loss, accuracy = modelo.evaluate(X_test,y_test)
print("Loss: ", loss)
print("Acurácia: ", accuracy)
# Out:
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9809
# Loss:  0.01732429675757885
# Acurácia:  0.980861246585846

# %%
nova_previsao = modelo.predict(X_test)
print(nova_previsao)
# Out:
# 53/53 [==============================] - 0s 4ms/step
# [[8.5130618e-11]
#  [5.5945097e-09]
#  [6.6293190e-08]
#  ...
#  [2.0365205e-15]
#  [1.7968249e-08]
#  [5.6360790e-04]]

# %%
prev = (nova_previsao > 0.5)
print(prev)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
cm = confusion_matrix(y_test, prev)
print(cm)
# Out:
# [[1423    5]
#  [  27  217]]
