# %%
# !pip install openai

# %%
import openai

# %%
openai.api_key = "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"

# %%
response = openai.Image.create(
    prompt="Crie uma imagem de um computador antigo",
    size="256x256",
    n=1,
    response_format = "url"
)
print(response["data"][0]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-xwZ46a0VAz9Ukf3gW4KerLHQ.png?st=2023-05-14T22%3A30%3A09Z&se=2023-05-15T00%3A30%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-05-13T23%3A58%3A35Z&ske=2023-05-14T23%3A58%3A35Z&sks=b&skv=2021-08-06&sig=gQK1A7lKuPbkyMzn0jcQbsGxEvMLjMfmiY0y/umxhVc%3D

# %%
response = openai.Image.create(
    prompt="Crie uma imagem de um computador antigo",
    size="512x512",
    n=1,
    response_format = "url"
)
print(response["data"][0]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-O4VnK4ZoPGzjT2Vmv8ASjHPn.png?st=2023-05-14T22%3A30%3A53Z&se=2023-05-15T00%3A30%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-05-14T09%3A34%3A00Z&ske=2023-05-15T09%3A34%3A00Z&sks=b&skv=2021-08-06&sig=nrwkIBknP4Uzm3/tBm1w0DTHKsv4qbFlsHj%2BRpUPHOI%3D

# %%
response = openai.Image.create(
    prompt="Crie uma imagem de um computador antigo",
    size="512x512",
    n=2,
    response_format = "url"
)
print(response["data"][0]["url"])
print(response["data"][1]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-ab33ey4IxThojyrGyy0GcjIQ.png?st=2023-05-14T22%3A31%3A36Z&se=2023-05-15T00%3A31%3A36Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-05-14T21%3A04%3A12Z&ske=2023-05-15T21%3A04%3A12Z&sks=b&skv=2021-08-06&sig=Qh9PvZZFzt5OguzDeu3pmyZkiRrSfQZH4rExrKQg4eU%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-lycFzW7jzPr0SdMaHIy8zZAG.png?st=2023-05-14T22%3A31%3A36Z&se=2023-05-15T00%3A31%3A36Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-05-14T21%3A04%3A12Z&ske=2023-05-15T21%3A04%3A12Z&sks=b&skv=2021-08-06&sig=jV5cgnUYfun/B6wXveiX52oMEV6WC0%2B/grULgSOWvN8%3D

# %%
from io import BytesIO
import requests
from PIL import Image
response = openai.Image.create(
    prompt="Crie uma imagem de um computador antigo",
    size="512x512",
    n=1,
    response_format = "url"
)
response = requests.get(response["data"][0]["url"])
Image.open(BytesIO(response.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FF2E09F2110>

# %%
import base64
from IPython.display import display
response = openai.Image.create(
    prompt="Crie uma imagem de um computador antigo",
    size="512x512",
    n=1,
    response_format = "b64_json"
)
imagem = response["data"][0]["b64_json"]
imagem = base64.b64decode(imagem)

with open("computador.png","wb") as f:
  f.write(imagem)

display(Image.open("computador.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FF2E09F23E0>
